# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishgeddam2002/data-science-assignment-excelr/blob/main/Neural_networks_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Alphabets_data.csv")
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %%
# Function to preprocess the data
def preprocess_data(df):
    # Encode target variable
    le = LabelEncoder()
    df['letter'] = le.fit_transform(df['letter'])

    # Split features and target variable
    X = df.drop(columns=['letter'])
    y = df['letter']

    # Standardize the features
    sc = StandardScaler()
    X = sc.fit_transform(X)

    return X, y

# %%
# Function to build the model
def build_model():
    model = Sequential()
    model.add(Dense(units=10, activation='relu', input_shape=(16,)))  # Input shape based on number of features
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Function to tune hyperparameters
def tune_hyperparameters(X_train, y_train, X_test, y_test):
    import keras_tuner as kt

    def optimizer_selection(hp):
        model = Sequential()
        model.add(Dense(units=10, activation='relu', input_shape=(16,)))
        model.add(Dense(units=1, activation='sigmoid'))

        optim = hp.Choice('optimizer', values=['sgd', 'adam', 'rmsprop'])
        model.compile(optimizer=optim, loss='binary_crossentropy', metrics=['accuracy'])
        return model

    tuner = kt.RandomSearch(
        optimizer_selection,
        objective='val_accuracy',
        max_trials=3
    )
    tuner.search(X_train, y_train, epochs=3, validation_data=(X_test, y_test))
    return tuner.get_best_hyperparameters()[0].values['optimizer']



# Data Exploration
print(df.describe())
print(df.head())
print(df.tail())
print(df.isna().sum())
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
# Preprocess data
X, y = preprocess_data(df)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Build and train the model
model = build_model()
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0712 - loss: 3.7347
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0706 - loss: 3.5804
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0717 - loss: 3.4285
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0685 - loss: 3.4968
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0733 - loss: 3.1294
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0688 - loss: 2.9752
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0730 - loss: 2.7626
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0729 - loss: 2.7989
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0736 - loss: 2.4298
# Epoch 10/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.0723 - loss: 2.3078
# Epoch 11/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0730 - loss: 2.1939
# Epoch 12/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0721 - loss: 1.8867
# Epoch 13/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0729 - loss: 1.7484
# Epoch 14/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0743 - loss: 1.5093
# Epoch 15/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0730 - loss: 1.4729
# Epoch 16/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0746 - loss: 1.1172
# Epoch 17/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0751 - loss: 0.8896
# Epoch 18/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0726 - loss: 0.9731
# Epoch 19/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0725 - loss: 0.5835
# Epoch 20/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0750 - loss: 0.5305
# Epoch 21/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0727 - loss: 0.3532
# Epoch 22/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0755 - loss: -0.0526
# Epoch 23/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0712 - loss: -0.1467
# Epoch 24/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0709 - loss: -0.2719
# Epoch 25/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0740 - loss: -0.4590
# Epoch 26/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0716 - loss: -0.6204
# Epoch 27/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0745 - loss: -0.8059
# Epoch 28/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0774 - loss: -1.0343
# Epoch 29/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0681 - loss: -1.1773
# Epoch 30/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0731 - loss: -1.3242
# Epoch 31/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0717 - loss: -1.6965
# Epoch 32/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0720 - loss: -1.7888
# Epoch 33/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0726 - loss: -2.1040
# Epoch 34/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0749 - loss: -2.0862
# Epoch 35/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0730 - loss: -2.2695
# Epoch 36/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0701 - loss: -2.7147
# Epoch 37/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0721 - loss: -2.6528
# Epoch 38/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0724 - loss: -2.8216
# Epoch 39/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0701 - loss: -3.2134
# Epoch 40/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0728 - loss: -3.3733
# Epoch 41/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0722 - loss: -3.4247
# Epoch 42/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0692 - loss: -3.7041
# Epoch 43/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0721 - loss: -3.7323
# Epoch 44/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0716 - loss: -4.0656
# Epoch 45/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0711 - loss: -4.2966
# Epoch 46/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0702 - loss: -4.5508
# Epoch 47/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0728 - loss: -4.7502
# Epoch 48/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0707 - loss: -4.6740
# Epoch 49/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0737 - loss: -4.9793
# Epoch 50/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0697 - loss: -5.1559
# Epoch 51/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0700 - loss: -5.2415
# Epoch 52/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0704 - loss: -5.5618
# Epoch 53/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0700 - loss: -5.6455
# Epoch 54/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0698 - loss: -6.1089
# Epoch 55/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0669 - loss: -6.1876
# Epoch 56/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0709 - loss: -6.2812
# Epoch 57/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0754 - loss: -6.3530
# Epoch 58/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0692 - loss: -6.5513
# Epoch 59/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0708 - loss: -6.8987
# Epoch 60/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0724 - loss: -6.9790
# Epoch 61/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0736 - loss: -7.1942
# Epoch 62/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0673 - loss: -7.3682
# Epoch 63/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0725 - loss: -7.7245
# Epoch 64/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0705 - loss: -7.8291
# Epoch 65/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0671 - loss: -7.9283
# Epoch 66/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0672 - loss: -8.1731
# Epoch 67/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0669 - loss: -8.4772
# Epoch 68/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0680 - loss: -8.7205
# Epoch 69/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0662 - loss: -8.6931
# Epoch 70/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0668 - loss: -9.0114
# Epoch 71/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0696 - loss: -9.2238
# Epoch 72/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0676 - loss: -9.2929
# Epoch 73/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0649 - loss: -9.4784
# Epoch 74/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0691 - loss: -9.7473
# Epoch 75/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0645 - loss: -9.9870
# Epoch 76/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0675 - loss: -9.9872
# Epoch 77/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0675 - loss: -10.1331
# Epoch 78/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0659 - loss: -10.5233
# Epoch 79/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0685 - loss: -10.4958
# Epoch 80/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0672 - loss: -10.9232
# Epoch 81/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0643 - loss: -11.2450
# Epoch 82/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0665 - loss: -11.1172
# Epoch 83/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0633 - loss: -11.3601
# Epoch 84/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0652 - loss: -11.5207
# Epoch 85/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0640 - loss: -11.6589
# Epoch 86/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0637 - loss: -11.9340
# Epoch 87/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0666 - loss: -12.0033
# Epoch 88/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0652 - loss: -12.6654
# Epoch 89/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0624 - loss: -12.5549
# Epoch 90/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0637 - loss: -12.6944
# Epoch 91/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0642 - loss: -12.7977
# Epoch 92/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0610 - loss: -13.2178
# Epoch 93/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0629 - loss: -13.3082
# Epoch 94/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0639 - loss: -13.2389
# Epoch 95/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0628 - loss: -13.3965
# Epoch 96/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0608 - loss: -13.8105
# Epoch 97/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0624 - loss: -14.0199
# Epoch 98/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0583 - loss: -14.2186
# Epoch 99/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0556 - loss: -14.4914
# Epoch 100/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0590 - loss: -14.7910

# %%
# Predict on test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary output
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Evaluate model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.59      0.32       162
#            1       0.04      1.00      0.08       152
#            2       0.00      0.00      0.00       144
#            3       0.00      0.00      0.00       156
#            4       0.00      0.00      0.00       139
#            5       0.00      0.00      0.00       144
#            6       0.00      0.00      0.00       154
#            7       0.00      0.00      0.00       146
#            8       0.00      0.00      0.00       138
#            9       0.00      0.00      0.00       141
#           10       0.00      0.00      0.00       137
#           11       0.00      0.00      0.00       139
#           12       0.00      0.00      0.00       145
#           13       0.00      0.00      0.00       161
#           14       0.00      0.00      0.00       173
#           15       0.00      0.00      0.00       174
#           16       0.00      0.00      0.00       159
#           17       0.00      0.00      0.00       157
#           18       0.00      0.00      0.00       170
#           19       0.00      0.00      0.00       181
#           20       0.00      0.00      0.00       161
#           21       0.00      0.00      0.00       142
#           22       0.00      0.00      0.00       151
#           23       0.00      0.00      0.00       154
#           24       0.00      0.00      0.00       162
#           25       0.00      0.00      0.00       158
#
#     accuracy                           0.06      4000
#    macro avg       0.01      0.06      0.02      4000
# weighted avg       0.01      0.06      0.02      4000

# %%
# Hyperparameter Tuning
best_optimizer = tune_hyperparameters(X_train, y_train, X_test, y_test)
print(f"Best optimizer: {best_optimizer}")
# Out:
# Trial 3 Complete [00h 00m 09s]
# val_accuracy: 0.04050000011920929
#
# Best val_accuracy So Far: 0.04050000011920929
# Total elapsed time: 00h 00m 29s
# Best optimizer: sgd

# %%
# Retrain model with the best hyperparameters
model = build_model()
model.compile(optimizer=best_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0381 - loss: nan - val_accuracy: 0.0380 - val_loss: nan
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0375 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0404 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0410 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0386 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0408 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0372 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0368 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0392 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 10/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0398 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 11/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0391 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 12/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0405 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 13/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0379 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 14/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0393 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 15/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0372 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 16/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0376 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 17/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0397 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 18/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0396 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 19/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0384 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 20/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 21/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 22/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0382 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 23/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0407 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 24/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0426 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 25/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0427 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 26/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0405 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 27/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0381 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 28/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0387 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 29/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0392 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 30/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0394 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 31/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0383 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 32/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0403 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 33/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0394 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 34/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0401 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 35/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0388 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 36/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0394 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 37/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0395 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 38/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0408 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 39/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0377 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 40/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 41/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0397 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 42/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0411 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 43/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0409 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 44/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0380 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 45/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0382 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 46/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0388 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 47/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0388 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 48/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0396 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 49/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0396 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 50/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0389 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 51/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0383 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 52/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0401 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 53/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0400 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 54/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0378 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 55/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0381 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 56/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0419 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 57/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0408 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 58/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0414 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 59/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 60/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0378 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 61/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0404 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 62/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0391 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 63/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0403 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 64/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0429 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 65/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0399 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 66/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0380 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 67/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0400 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 68/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0393 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 69/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0402 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 70/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0382 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 71/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 72/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0412 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 73/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0374 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 74/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0402 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 75/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0395 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 76/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0405 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 77/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0365 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 78/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 79/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0389 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 80/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.0408 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 81/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0382 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 82/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0388 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 83/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0420 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 84/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0387 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 85/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0376 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 86/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0375 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 87/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0348 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 88/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0385 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 89/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0402 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 90/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0385 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 91/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0398 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 92/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0397 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 93/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0387 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 94/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0400 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 95/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0358 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 96/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0403 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 97/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0400 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 98/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0392 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 99/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0412 - loss: nan - val_accuracy: 0.0405 - val_loss: nan
# Epoch 100/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0390 - loss: nan - val_accuracy: 0.0405 - val_loss: nan

# %%
# Evaluate the final model
evaluation = model.evaluate(X_train, y_train)
print(f"Final Model - Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0380 - loss: nan
# Final Model - Loss: nan, Accuracy: 0.03918749839067459

# %% [markdown]
# Conclusion :
#
# The code has been refactored for clarity and modularity, with functions for loading data, preprocessing, building models, and tuning hyperparameters. It ensures better organization, improved handling of predictions, and efficient hyperparameter tuning for optimizing model performance.
